# %%
import pandas as pd
import pymongo

df=pd.read_csv('C:/yeshwanth/github_repos/MLOPS-MOVIE-RECOMMENDATION-SYSTEM/notebook/df_movies.csv')
df.head()
# Out:
#         id                             title  \
# 0   533533                        TRON: Ares
# 1  1180831                           Troll 2
# 2  1083637     Kantara - A Legend: Chapter 1
# 3    23527  First Squad: The Moment of Truth
# 4  1448560                           Wildcat
#
#                                             overview  \
# 0  A highly sophisticated Program called Ares is ...
# 1  When a dangerous new troll unleashes devastati...
# 2  During the Kadamba reign, King Vijayendra, the...
# 3  Set during the opening days of World War II on...
# 4  An ex-black ops team reunite to pull off a des...
#
#                                               genres  \
# 0         ['Science Fiction', 'Adventure', 'Action']
# 1                  ['Action', 'Fantasy', 'Thriller']
# 2                     ['Action', 'Drama', 'Fantasy']
# 3  ['Fantasy', 'Animation', 'Action', 'Science Fi...
# 4                    ['Action', 'Thriller', 'Crime']
#
# ...

# %%
#df should be converted into dictionary before pushing into mongodb
data=df.to_dict(orient='records')
data
# Out:
# [{'id': 533533,
#   'title': 'TRON: Ares',
#   'overview': "A highly sophisticated Program called Ares is sent from the digital world into the real world on a dangerous mission, marking humankind's first encounter with A.I. beings.",
#   'genres': "['Science Fiction', 'Adventure', 'Action']",
#   'cast': "['Jared Leto', 'Greta Lee', 'Evan Peters', 'Gillian Anderson', 'Jodie Turner-Smith', 'Jeff Bridges', 'Hasan Minhaj', 'Arturo Castro', 'Cameron Monaghan', 'Sarah Desjardins']",
#   'director': 'Joachim Rønning',
#   'keywords': "['artificial intelligence (a.i.)', 'computer program', 'simulation', 'computer simulation', 'sequel', 'business rivalry', 'real world', 'digital world']",
#   'rating': 6.548,
#   'vote_count': 656,
#   'release_date': '2025-10-08',
#   'imdb_rating': nan,
#   'imdb_votes': nan,
#   'poster_url': 'https://image.tmdb.org/t/p/w500/chpWmskl3aKm1aTZqUHRCtviwPy.jpg',
#   'backdrop_url': 'https://image.tmdb.org/t/p/w500/min9ZUDZbiguTiQ7yz1Hbqk78HT.jpg'},
# ...

# %%
df.shape
# Out:
# (1635, 14)

# %%
DB_NAME = "movie_recommender"
COLLECTION_NAME = "movies_metadata"

CONNECTION_URL='mongodb+srv://shivakeshava1809_db_user:MAnT4yAbptYYjrvg@cluster0.3ahti1w.mongodb.net/?appName=Cluster0'

# %%
client=pymongo.MongoClient(CONNECTION_URL)
data_base=client[DB_NAME]
collection=data_base[COLLECTION_NAME]

# %%
from pymongo import MongoClient

client = MongoClient(CONNECTION_URL, serverSelectionTimeoutMS=5000)

print(client.admin.command("ping"))
# Out:
# {'ok': 1}

# %%
# Uploading data to MongoDB
rec=collection.insert_many(data)

# %%
df.shape
# Out:
# (1635, 14)

# %%
df.isnull().sum()
# Out:
# id                 0
# title              0
# overview           0
# genres             0
# cast               0
# director           0
# keywords           0
# rating             0
# vote_count         0
# release_date       0
# imdb_rating     1627
# imdb_votes      1626
# poster_url         0
# backdrop_url      13
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1635 entries, 0 to 1634
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1635 non-null   int64
#  1   title         1635 non-null   object
#  2   overview      1635 non-null   object
#  3   genres        1635 non-null   object
#  4   cast          1635 non-null   object
#  5   director      1635 non-null   object
#  6   keywords      1635 non-null   object
#  7   rating        1635 non-null   float64
#  8   vote_count    1635 non-null   int64
#  9   release_date  1635 non-null   object
#  10  imdb_rating   8 non-null      float64
#  11  imdb_votes    9 non-null      object
#  12  poster_url    1635 non-null   object
#  13  backdrop_url  1622 non-null   object
# dtypes: float64(2), int64(2), object(10)
# memory usage: 179.0+ KB

# %%
#dropping the columns fo imbd_rating and imbd_votes
df = df.drop(columns=["imdb_rating", "imdb_votes"], errors="ignore")

# %%
df.isnull().sum()
# Out:
# id               0
# title            0
# overview         0
# genres           0
# cast             0
# director         0
# keywords         0
# rating           0
# vote_count       0
# release_date     0
# poster_url       0
# backdrop_url    13
# dtype: int64

# %%
df.describe()
# Out:
#                  id       rating    vote_count
# count  1.635000e+03  1635.000000   1635.000000
# mean   4.234760e+05     6.797229   3611.424465
# std    4.662535e+05     0.920127   6113.958300
# min    1.100000e+01     3.115000     11.000000
# 25%    1.480300e+04     6.229500     64.000000
# 50%    2.420950e+05     6.899000    527.000000
# 75%    7.877230e+05     7.452000   4278.000000
# max    1.589891e+06     9.316000  38360.000000

# %%
# Remove rows where 'keywords' column has missing values
df = df.dropna(subset=['keywords'])

# %%
df.isnull().sum()
# Out:
# id               0
# title            0
# overview         0
# genres           0
# cast             0
# director         0
# keywords         0
# rating           0
# vote_count       0
# release_date     0
# poster_url       0
# backdrop_url    13
# dtype: int64

# %%
df.shape
# Out:
# (1635, 12)
